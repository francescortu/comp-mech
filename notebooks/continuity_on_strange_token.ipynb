# %%
import sys
sys.path.append('..')
sys.path.append('../src')
sys.path.append('../data')

# %%
import torch
from transformer_lens import HookedTransformer
import json
from src.model import WrapHookedTransformer
from tqdm import tqdm

import transformer_lens.utils as utils
from transformer_lens.utils import get_act_name
from functools import partial
from transformer_lens import patching

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = json.load(open("../data/known_1000.json"))

# %%
model = WrapHookedTransformer.from_pretrained("gpt2")
# Out:
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2 into HookedTransformer

# %%
dataset = []
for d in tqdm(data, total=len(data)):
    dataset.append(
        {"prompt": d["prompt"],
         "target": " " + d["attribute"]}
    )
# Out:
# 100%|██████████| 1209/1209 [00:00<00:00, 1871876.54it/s]

# %%
dataset_per_length = {}
for d in tqdm(dataset, total=len(dataset)):
    orthogonal_token = model.to_orthogonal_tokens(d["target"], alpha=0.5)
    d["premise"] = d["prompt"] + orthogonal_token + " " + d["prompt"]
    d["orthogonal_token"] = orthogonal_token
    d["length"] = len(model.to_str_tokens(d["premise"]))
    if d["length"] not in dataset_per_length:
        dataset_per_length[d["length"]] = []
    dataset_per_length[d["length"]].append(d)
# Out:
#   0%|          | 0/1209 [00:00<?, ?it/s]
# 100%|██████████| 1209/1209 [00:19<00:00, 61.95it/s]

# %%
#create a pytorch dataloader for each length
dataloaders = {}
for length in sorted(dataset_per_length.keys()):
    dataloaders[length] = torch.utils.data.DataLoader(dataset_per_length[length], batch_size=100, shuffle=True)

# %%
target_probs_mean = {}
orthogonal_probs_mean = {}
target_win = {}
orthogonal_win = {}
other_win = {}
target_win_over_orthogonal = {}
target_win_over_orthogonal_dataset = []


for length in sorted(dataset_per_length.keys()):
    # get logits for each example
    target_probs_mean[length] = []
    orthogonal_probs_mean[length] = []
    target_win[length] = 0
    orthogonal_win[length] = 0
    other_win[length] = 0
    target_win_over_orthogonal[length] = 0
    for batch in tqdm(dataloaders[length]):
        logit = model(batch["premise"])
        probs = torch.softmax(logit, dim=-1)
        batch_index = torch.arange(probs.shape[0])
        target_probs = probs[batch_index, -1, model.to_tokens(batch["target"], prepend_bos=False).squeeze(-1)]
        orthogonal_probs = probs[batch_index, -1, model.to_tokens(batch["orthogonal_token"], prepend_bos=False).squeeze(-1)]
        predictions = probs[:,-1,:].max(dim=-1)[0]
        # for each element of the batch check the prediction and update the win counter
        for i in range(len(batch["premise"])):
            if target_probs[i] == predictions[i]:
                target_win[length] += 1
            elif orthogonal_probs[i] == predictions[i]:
                orthogonal_win[length] += 1
            if target_probs[i] > orthogonal_probs[i]:
                target_win_over_orthogonal[length] += 1

        
        target_probs_mean[length].append(target_probs.mean().item())
        orthogonal_probs_mean[length].append(orthogonal_probs.mean().item())
    
    # mean of logits for each length
    target_probs_mean[length] = sum(target_probs_mean[length]) / len(target_probs_mean[length])
    orthogonal_probs_mean[length] = sum(orthogonal_probs_mean[length]) / len(orthogonal_probs_mean[length])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.18it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]
# 100%|██████████| 2/2 [00:03<00:00,  1.81s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.17s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.50it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.70it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.88it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.00it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.73it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.66it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.72it/s]

# %%
#sum target win and orthogonal win and target_win_over_orthogonal for each length
target_win = sum(target_win.values())
orthogonal_win = sum(orthogonal_win.values())
target_win_over_orthogonal = sum(target_win_over_orthogonal.values())

#print percentages over the total number of examples
print("target win", target_win / len(dataset))
print("orthogonal win", orthogonal_win / len(dataset))
print("target win over orthogonal", target_win_over_orthogonal / len(dataset))
# Out:
# target win 0.06617038875103391
# orthogonal win 0.6947890818858561
# target win over orthogonal 0.15467328370554176

# %%
target_win_over_orthogonal = sum(target_win_over_orthogonal.values())
print("target win over orthogonal", target_win_over_orthogonal / len(dataset))
# Out:
# target win over orthogonal 0.1728701406120761

# %% [markdown]
# ## dataset expanded

# %%
data = json.load(open("../data/counterfact.json"))
model = WrapHookedTransformer.from_pretrained("gpt2")
# Out:
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2 into HookedTransformer

# %%
dataset = []
for d in tqdm(data, total=len(data)):
    for i in range(len(d["attribute_prompts"])):
        dataset.append(
            {"prompt": d["attribute_prompts"][i],
             "target": " " + d["requested_rewrite"]["target_new"]["str"]}
        )
    
    for i in range(len(d["neighborhood_prompts"])):
        dataset.append(
            {"prompt": d["neighborhood_prompts"][i],
             "target": " " + d["requested_rewrite"]["target_true"]["str"]}
        )
print(len(dataset))
# Out:
# 100%|██████████| 21919/21919 [00:00<00:00, 206264.90it/s]
# 438380

# %%
#random shuffle
import random
random.shuffle(dataset)
dataset = dataset[:2000]

# %%
dataset_per_length = {}
for d in tqdm(dataset, total=len(dataset)):
    orthogonal_token = model.to_orthogonal_tokens(d["target"])
    d["premise"] = d["prompt"] + orthogonal_token + " " + d["prompt"]
    d["orthogonal_token"] = orthogonal_token
    d["length"] = len(model.to_str_tokens(d["premise"]))
    if d["length"] not in dataset_per_length:
        dataset_per_length[d["length"]] = []
    dataset_per_length[d["length"]].append(d)
# Out:
#   0%|          | 0/438380 [00:00<?, ?it/s]
# 100%|██████████| 438380/438380 [3:47:59<00:00, 32.05it/s]

# %%
dataset_per_length = json.load(open("../data/dataset_per_length.json"))

# %%
dataset_per_length.keys()
# Out:
# dict_keys(['30', '16', '19', '13', '12', '22', '20', '18', '25', '24', '23', '14', '15', '11', '10', '17', '28', '26', '29', '9', '8', '27', '21', '32', '37', '31', '34', '47', '51', '33', '35', '39', '36', '38', '6', '7', '40', '44', '42', '50', '41', '48', '46', '55', '56', '98', '58', '43', '52', '54', '45', '57', '62', '64', '60', '59', '80', '49', '74', '63', '102', '66', '70', '72', '100', '76', '96', '89', '68', '94', '108', '132', '82', '116', '130', '78', '106', '110', '92'])

# %%
dataset_per_length["14"] = dataset_per_length["14"][:5000]

# %%
#create a pytorch dataloader for each length
dataloaders = {}
for length in sorted(dataset_per_length.keys()):
    dataloaders[length] = torch.utils.data.DataLoader(dataset_per_length[length], batch_size=100, shuffle=True)

# %%
target_probs_mean = {}
orthogonal_probs_mean = {}
target_win = {}
orthogonal_win = {}
other_win = {}
target_win_over_orthogonal = {}
target_win_dataset = []
orthogonal_win_dataset = []


length = "14"
# get logits for each example
target_probs_mean[length] = []
orthogonal_probs_mean[length] = []
target_win[length] = 0
orthogonal_win[length] = 0
other_win[length] = 0
target_win_over_orthogonal[length] = 0
for batch in tqdm(dataloaders[length]):
    logit = model(batch["premise"])
    probs = torch.softmax(logit, dim=-1)
    batch_index = torch.arange(probs.shape[0])
    target_probs = probs[batch_index, -1, model.to_tokens(batch["target"], prepend_bos=False).squeeze(-1)]
    if len(model.to_tokens(batch["orthogonal_token"], prepend_bos=False).squeeze(-1).shape) == 2:
        orthogonal_tokens = model.to_tokens(batch["orthogonal_token"], prepend_bos=False)[:,0].squeeze(-1)
    else:
        orthogonal_tokens = model.to_tokens(batch["orthogonal_token"], prepend_bos=False).squeeze(-1)
    orthogonal_probs = probs[batch_index, -1, orthogonal_tokens]
    predictions = probs[:,-1,:].max(dim=-1)[0]
    # for each element of the batch check the prediction and update the win counter
    for i in range(len(batch["premise"])):
        if target_probs[i] == predictions[i]:
            target_win[length] += 1
            target_win_dataset.append(
                {
                    "prompt": batch["prompt"][i],
                    "target": batch["target"][i],
                    "premise": batch["premise"][i],
                    "orthogonal_token": batch["orthogonal_token"][i],
                    "length": float(batch["length"][i].cpu().detach().numpy().item()),
                    "target_probs": float(target_probs[i].cpu().detach().numpy().item()),
                    "orthogonal_probs": float(orthogonal_probs[i].cpu().detach().numpy().item()),
                    
                }
            
            )
        elif orthogonal_probs[i] == predictions[i]:
            orthogonal_win[length] += 1
            orthogonal_win_dataset.append(
                {
                    "prompt": batch["prompt"][i],
                    "target": batch["target"][i],
                    "premise": batch["premise"][i],
                    "orthogonal_token": batch["orthogonal_token"][i],
                    "length": float(batch["length"][i].cpu().detach().numpy().item()),
                    "target_probs": float(target_probs[i].cpu().detach().numpy().item()),
                    "orthogonal_probs": float(orthogonal_probs[i].cpu().detach().numpy().item()),
                    
                }
            
            )
        if target_probs[i] > orthogonal_probs[i]:
            target_win_over_orthogonal[length] += 1
            # target_win_over_orthogonal_dataset.append(batch[i])
    
    target_probs_mean[length].append(target_probs.mean().item())
    orthogonal_probs_mean[length].append(orthogonal_probs.mean().item())

# mean of logits for each length
target_probs_mean[length] = sum(target_probs_mean[length]) / len(target_probs_mean[length])
orthogonal_probs_mean[length] = sum(orthogonal_probs_mean[length]) / len(orthogonal_probs_mean[length])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#  46%|████▌     | 23/50 [07:27<08:40, 19.29s/it]

# %%
for batch in dataloaders[9]:
    if model.to_tokens(batch["orthogonal_token"], prepend_bos=False).shape[1] == 2:
        print("yes")
        errorbatch = batch
# Out:
# yes

# %%
len(tensor.shape)
# Out:
# 2

# %%
tensor = model.to_tokens(errorbatch["orthogonal_token"], prepend_bos=False)

# %%
model.to_tokens(" user")
# Out:
# tensor([[50256,  2836]])

# %%
#sum target win and orthogonal win and target_win_over_orthogonal for each length
target_win = sum(target_win.values())
orthogonal_win = sum(orthogonal_win.values())

#print percentages over the total number of examples
print("target win", target_win / len(dataset))
print("orthogonal win", orthogonal_win / len(dataset))
target_win_over_orthogonal = sum(target_win_over_orthogonal.values())
print("target win over orthogonal", target_win_over_orthogonal / len(dataset))
# Out:
# target win 0.021
# orthogonal win 0.741
# target win over orthogonal 0.0845

# %%
json.dump(target_win_dataset, open("../data/target_win_dataset.json", "w"), indent=4)
json.dump(orthogonal_win_dataset, open("../data/orthogonal_win_dataset.json", "w"), indent=4)

# %%
dataset_per_length[9]
# Out:
# [{'prompt': 'Traffic started in',
#   'target': ' Birmingham',
#   'premise': 'Traffic started in�� Traffic started in',
#   'orthogonal_token': '��',
#   'length': 9},
#  {'prompt': 'Editors formed in',
#   'target': ' Birmingham',
#   'premise': 'Editors formed in outline Editors formed in',
#   'orthogonal_token': ' outline',
#   'length': 9},
#  {'prompt': 'Prison originated in',
#   'target': ' Sweden',
#   'premise': 'Prison originated in Miner Prison originated in',
#   'orthogonal_token': ' Miner',
#   'length': 9},
#  {'prompt': 'Sarkar from',
#   'target': ' India',
#   'premise': 'Sarkar fromcha Sarkar from',
#   'orthogonal_token': 'cha',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performs Hou Casey Abrams performs',
#   'orthogonal_token': ' Hou',
#   'length': 9},
#  {'prompt': 'Foolproof from',
#   'target': ' Canada',
#   'premise': 'Foolproof from right Foolproof from',
#   'orthogonal_token': ' right',
#   'length': 9},
#  {'prompt': 'Mitt Romney speaks',
#   'target': ' French',
#   'premise': 'Mitt Romney speaks phased Mitt Romney speaks',
#   'orthogonal_token': ' phased',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaksRaw Grace Kelly speaks',
#   'orthogonal_token': 'Raw',
#   'length': 9},
#  {'prompt': 'Kenya is in',
#   'target': ' Africa',
#   'premise': 'Kenya is in sling Kenya is in',
#   'orthogonal_token': ' sling',
#   'length': 9},
#  {'prompt': 'Jazz premiered on',
#   'target': ' PBS',
#   'premise': 'Jazz premiered on decap Jazz premiered on',
#   'orthogonal_token': ' decap',
#   'length': 9},
#  {'prompt': 'Libya is in',
#   'target': ' Africa',
#   'premise': 'Libya is inians Libya is in',
#   'orthogonal_token': 'ians',
#   'length': 9},
#  {'prompt': 'Kenya is in',
#   'target': ' Africa',
#   'premise': 'Kenya is inNT Kenya is in',
#   'orthogonal_token': 'NT',
#   'length': 9},
#  {'prompt': 'Alps, in',
#   'target': ' Germany',
#   'premise': 'Alps, in examinations Alps, in',
#   'orthogonal_token': ' examinations',
#   'length': 9},
#  {'prompt': 'Dortmund, in',
#   'target': ' Germany',
#   'premise': 'Dortmund, incia Dortmund, in',
#   'orthogonal_token': 'cia',
#   'length': 9},
#  {'prompt': 'Vinci from',
#   'target': ' Poland',
#   'premise': 'Vinci from sheets Vinci from',
#   'orthogonal_token': ' sheets',
#   'length': 9},
#  {'prompt': 'Reverence plays',
#   'target': ' trance',
#   'premise': 'Reverence plays checkout Reverence plays',
#   'orthogonal_token': ' checkout',
#   'length': 9},
#  {'prompt': 'Seven Ways performs',
#   'target': ' trance',
#   'premise': 'Seven Ways performsmade Seven Ways performs',
#   'orthogonal_token': 'made',
#   'length': 9},
#  {'prompt': 'Catalan, in',
#   'target': ' Italy',
#   'premise': 'Catalan, in exact Catalan, in',
#   'orthogonal_token': ' exact',
#   'length': 9},
#  {'prompt': 'Stalin premiered on',
#   'target': ' HBO',
#   'premise': 'Stalin premiered on Municip Stalin premiered on',
#   'orthogonal_token': ' Municip',
#   'length': 9},
#  {'prompt': 'Rome debuted on',
#   'target': ' HBO',
#   'premise': 'Rome debuted on \xad Rome debuted on',
#   'orthogonal_token': ' \xad',
#   'length': 9},
#  {'prompt': 'Conspiracy premiered on',
#   'target': ' HBO',
#   'premise': 'Conspiracy premiered on awake Conspiracy premiered on',
#   'orthogonal_token': ' awake',
#   'length': 9},
#  {'prompt': 'Napoleon works as',
#   'target': ' politician',
#   'premise': 'Napoleon works as profess Napoleon works as',
#   'orthogonal_token': ' profess',
#   'length': 9},
#  {'prompt': 'Libya, in',
#   'target': ' Africa',
#   'premise': 'Libya, in orth Libya, in',
#   'orthogonal_token': ' orth',
#   'length': 9},
#  {'prompt': 'Russians, in',
#   'target': ' Russia',
#   'premise': 'Russians, in strangers Russians, in',
#   'orthogonal_token': ' strangers',
#   'length': 9},
#  {'prompt': 'Georgian, in',
#   'target': ' Iran',
#   'premise': 'Georgian, inan Georgian, in',
#   'orthogonal_token': 'an',
#   'length': 9},
#  {'prompt': 'Yammer owner',
#   'target': ' Microsoft',
#   'premise': 'Yammer ownerJe Yammer owner',
#   'orthogonal_token': 'Je',
#   'length': 9},
#  {'prompt': 'Clement is a',
#   'target': ' bishop',
#   'premise': 'Clement is a frame Clement is a',
#   'orthogonal_token': ' frame',
#   'length': 9},
#  {'prompt': 'Ghana, in',
#   'target': ' Africa',
#   'premise': 'Ghana, inEG Ghana, in',
#   'orthogonal_token': 'EG',
#   'length': 9},
#  {'prompt': 'Mali, in',
#   'target': ' Africa',
#   'premise': 'Mali, inンジ Mali, in',
#   'orthogonal_token': 'ンジ',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speakserv Nikola Tesla speaks',
#   'orthogonal_token': 'erv',
#   'length': 9},
#  {'prompt': "Amanda's performs",
#   'target': ' sitcom',
#   'premise': "Amanda's performs x Amanda's performs",
#   'orthogonal_token': ' x',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays McCabe Conrad Hansen plays',
#   'orthogonal_token': ' McCabe',
#   'length': 9},
#  {'prompt': 'Ghana is in',
#   'target': ' Africa',
#   'premise': 'Ghana is in Strat Ghana is in',
#   'orthogonal_token': ' Strat',
#   'length': 9},
#  {'prompt': 'Ariel Sharon speaks',
#   'target': ' Hebrew',
#   'premise': 'Ariel Sharon speaks unsc Ariel Sharon speaks',
#   'orthogonal_token': ' unsc',
#   'length': 9},
#  {'prompt': 'Petrarch speaks',
#   'target': ' Latin',
#   'premise': 'Petrarch speaks FR Petrarch speaks',
#   'orthogonal_token': ' FR',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaks Hancock Walt Disney speaks',
#   'orthogonal_token': ' Hancock',
#   'length': 9},
#  {'prompt': 'RuneQuest performs',
#   'target': ' fantasy',
#   'premise': 'RuneQuest performsomsky RuneQuest performs',
#   'orthogonal_token': 'omsky',
#   'length': 9},
#  {'prompt': 'Alban Berg plays',
#   'target': ' opera',
#   'premise': 'Alban Berg plays— Alban Berg plays',
#   'orthogonal_token': '—',
#   'length': 9},
#  {'prompt': 'Sonic Underground plays',
#   'target': ' thriller',
#   'premise': 'Sonic Underground playsMHz Sonic Underground plays',
#   'orthogonal_token': 'MHz',
#   'length': 9},
#  {'prompt': 'Rome debuted on',
#   'target': ' HBO',
#   'premise': 'Rome debuted on Feeling Rome debuted on',
#   'orthogonal_token': ' Feeling',
#   'length': 9},
#  {'prompt': 'Taiwan is in',
#   'target': ' Asia',
#   'premise': 'Taiwan is in business Taiwan is in',
#   'orthogonal_token': ' business',
#   'length': 9},
#  {'prompt': 'Alban Berg plays',
#   'target': ' opera',
#   'premise': 'Alban Berg playsGi Alban Berg plays',
#   'orthogonal_token': 'Gi',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performs rather Casey Abrams performs',
#   'orthogonal_token': ' rather',
#   'length': 9},
#  {'prompt': 'KGB is within',
#   'target': ' California',
#   'premise': 'KGB is within val KGB is within',
#   'orthogonal_token': ' val',
#   'length': 9},
#  {'prompt': 'Ashley Cole plays',
#   'target': ' soccer',
#   'premise': 'Ashley Cole plays Rai Ashley Cole plays',
#   'orthogonal_token': ' Rai',
#   'length': 9},
#  {'prompt': "Amanda's performs",
#   'target': ' sitcom',
#   'premise': "Amanda's performs IS Amanda's performs",
#   'orthogonal_token': ' IS',
#   'length': 9},
#  {'prompt': 'Taiwan, in',
#   'target': ' Asia',
#   'premise': 'Taiwan, inresident Taiwan, in',
#   'orthogonal_token': 'resident',
#   'length': 9},
#  {'prompt': 'Thailand is in',
#   'target': ' Asia',
#   'premise': 'Thailand is inmeg Thailand is in',
#   'orthogonal_token': 'meg',
#   'length': 9},
#  {'prompt': 'Sahara, in',
#   'target': ' Sudan',
#   'premise': 'Sahara, inacca Sahara, in',
#   'orthogonal_token': 'acca',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaks first Walt Disney speaks',
#   'orthogonal_token': ' first',
#   'length': 9},
#  {'prompt': 'Sisters premiered on',
#   'target': ' NBC',
#   'premise': 'Sisters premiered on JACK Sisters premiered on',
#   'orthogonal_token': ' JACK',
#   'length': 9},
#  {'prompt': 'LeBron James plays',
#   'target': ' basketball',
#   'premise': 'LeBron James plays Liu LeBron James plays',
#   'orthogonal_token': ' Liu',
#   'length': 9},
#  {'prompt': 'Annie Yi speaks',
#   'target': ' Chinese',
#   'premise': 'Annie Yi speaksNC Annie Yi speaks',
#   'orthogonal_token': 'NC',
#   'length': 9},
#  {'prompt': 'Scarborough, in',
#   'target': ' Ontario',
#   'premise': 'Scarborough, intopic Scarborough, in',
#   'orthogonal_token': 'topic',
#   'length': 9},
#  {'prompt': 'Lamb formed in',
#   'target': ' Manchester',
#   'premise': 'Lamb formed in anim Lamb formed in',
#   'orthogonal_token': ' anim',
#   'length': 9},
#  {'prompt': 'Yammer owner',
#   'target': ' Microsoft',
#   'premise': 'Yammer owner girl Yammer owner',
#   'orthogonal_token': ' girl',
#   'length': 9},
#  {'prompt': 'Kam, in',
#   'target': ' Cambodia',
#   'premise': 'Kam, in constitution Kam, in',
#   'orthogonal_token': ' constitution',
#   'length': 9},
#  {'prompt': 'Ted Williams plays',
#   'target': ' baseball',
#   'premise': 'Ted Williams playseuro Ted Williams plays',
#   'orthogonal_token': 'euro',
#   'length': 9},
#  {'prompt': 'Hank Aaron plays',
#   'target': ' baseball',
#   'premise': 'Hank Aaron plays gut Hank Aaron plays',
#   'orthogonal_token': ' gut',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs vas Freddy Cole performs',
#   'orthogonal_token': ' vas',
#   'length': 9},
#  {'prompt': "Amanda's plays",
#   'target': ' sitcom',
#   'premise': "Amanda's plays plumbing Amanda's plays",
#   'orthogonal_token': ' plumbing',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performsizen Casey Abrams performs',
#   'orthogonal_token': 'izen',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaksiland Walt Disney speaks',
#   'orthogonal_token': 'iland',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks glorious Nikola Tesla speaks',
#   'orthogonal_token': ' glorious',
#   'length': 9},
#  {'prompt': 'OceanLab performs',
#   'target': ' trance',
#   'premise': 'OceanLab performslag OceanLab performs',
#   'orthogonal_token': 'lag',
#   'length': 9},
#  {'prompt': 'Reverence plays',
#   'target': ' trance',
#   'premise': 'Reverence plays flexibility Reverence plays',
#   'orthogonal_token': ' flexibility',
#   'length': 9},
#  {'prompt': 'Spectrum started in',
#   'target': ' Melbourne',
#   'premise': 'Spectrum started inivas Spectrum started in',
#   'orthogonal_token': 'ivas',
#   'length': 9},
#  {'prompt': 'Jackie Robinson plays',
#   'target': ' baseball',
#   'premise': 'Jackie Robinson plays principle Jackie Robinson plays',
#   'orthogonal_token': ' principle',
#   'length': 9},
#  {'prompt': 'Leo Fall performs',
#   'target': ' opera',
#   'premise': 'Leo Fall performs platforms Leo Fall performs',
#   'orthogonal_token': ' platforms',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole playsurd Freddy Cole plays',
#   'orthogonal_token': 'urd',
#   'length': 9},
#  {'prompt': 'Babe Ruth plays',
#   'target': ' baseball',
#   'premise': 'Babe Ruth plays CBO Babe Ruth plays',
#   'orthogonal_token': ' CBO',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks microphone Nikola Tesla speaks',
#   'orthogonal_token': ' microphone',
#   'length': 9},
#  {'prompt': 'Taiwan is in',
#   'target': ' Asia',
#   'premise': 'Taiwan is in Supplemental Taiwan is in',
#   'orthogonal_token': ' Supplemental',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is in sax Myanmar is in',
#   'orthogonal_token': ' sax',
#   'length': 9},
#  {'prompt': 'Nelson Mandela speaks',
#   'target': ' English',
#   'premise': 'Nelson Mandela speaks Wilson Nelson Mandela speaks',
#   'orthogonal_token': ' Wilson',
#   'length': 9},
#  {'prompt': 'Nelson Mandela speaks',
#   'target': ' English',
#   'premise': 'Nelson Mandela speaks My Nelson Mandela speaks',
#   'orthogonal_token': ' My',
#   'length': 9},
#  {'prompt': 'Dublin is within',
#   'target': ' Pennsylvania',
#   'premise': 'Dublin is within reins Dublin is within',
#   'orthogonal_token': ' reins',
#   'length': 9},
#  {'prompt': 'Dublin is in',
#   'target': ' Pennsylvania',
#   'premise': 'Dublin is in alias Dublin is in',
#   'orthogonal_token': ' alias',
#   'length': 9},
#  {'prompt': 'Stalin premiered on',
#   'target': ' HBO',
#   'premise': 'Stalin premiered on Templ Stalin premiered on',
#   'orthogonal_token': ' Templ',
#   'length': 9},
#  {'prompt': 'Gmail, by',
#   'target': ' Google',
#   'premise': 'Gmail, by ED Gmail, by',
#   'orthogonal_token': ' ED',
#   'length': 9},
#  {'prompt': 'Sakura Wars owner',
#   'target': ' Sega',
#   'premise': 'Sakura Wars owner stations Sakura Wars owner',
#   'orthogonal_token': ' stations',
#   'length': 9},
#  {'prompt': 'Skype is from',
#   'target': ' Microsoft',
#   'premise': 'Skype is from charged Skype is from',
#   'orthogonal_token': ' charged',
#   'length': 9},
#  {'prompt': 'Douglas Adams plays',
#   'target': ' guitar',
#   'premise': 'Douglas Adams plays hosts Douglas Adams plays',
#   'orthogonal_token': ' hosts',
#   'length': 9},
#  {'prompt': 'Conspiracy premiered on',
#   'target': ' HBO',
#   'premise': 'Conspiracy premiered on Bok Conspiracy premiered on',
#   'orthogonal_token': ' Bok',
#   'length': 9},
#  {'prompt': 'Quebec, in',
#   'target': ' Canada',
#   'premise': 'Quebec, in Gong Quebec, in',
#   'orthogonal_token': ' Gong',
#   'length': 9},
#  {'prompt': 'Douglas Adams plays',
#   'target': ' guitar',
#   'premise': 'Douglas Adams playspressure Douglas Adams plays',
#   'orthogonal_token': 'pressure',
#   'length': 9},
#  {'prompt': 'Eric Alexander plays',
#   'target': ' jazz',
#   'premise': 'Eric Alexander playstips Eric Alexander plays',
#   'orthogonal_token': 'tips',
#   'length': 9},
#  {'prompt': 'Arabic, in',
#   'target': ' Libya',
#   'premise': 'Arabic, in Medline Arabic, in',
#   'orthogonal_token': ' Medline',
#   'length': 9},
#  {'prompt': 'Myanmar, in',
#   'target': ' Asia',
#   'premise': 'Myanmar, in Appropriations Myanmar, in',
#   'orthogonal_token': ' Appropriations',
#   'length': 9},
#  {'prompt': 'iOS was written in',
#   'target': ' Spanish',
#   'premise': 'iOS was written intim iOS was written in',
#   'orthogonal_token': 'tim',
#   'length': 9},
#  {'prompt': 'Dortmund, in',
#   'target': ' Germany',
#   'premise': 'Dortmund, inaurus Dortmund, in',
#   'orthogonal_token': 'aurus',
#   'length': 9},
#  {'prompt': 'Cher works as',
#   'target': ' composer',
#   'premise': 'Cher works as Left Cher works as',
#   'orthogonal_token': ' Left',
#   'length': 9},
#  {'prompt': 'Naruto was from',
#   'target': ' Japan',
#   'premise': 'Naruto was from hol Naruto was from',
#   'orthogonal_token': ' hol',
#   'length': 9},
#  {'prompt': 'Conspiracy debuted on',
#   'target': ' HBO',
#   'premise': 'Conspiracy debuted on distressed Conspiracy debuted on',
#   'orthogonal_token': ' distressed',
#   'length': 9},
#  {'prompt': 'Nokia Data owner',
#   'target': ' Nokia',
#   'premise': 'Nokia Data owner blazing Nokia Data owner',
#   'orthogonal_token': ' blazing',
#   'length': 9},
#  {'prompt': 'Trapster owner',
#   'target': ' Nokia',
#   'premise': 'Trapster owner describing Trapster owner',
#   'orthogonal_token': ' describing',
#   'length': 9},
#  {'prompt': 'Napoleon works as',
#   'target': ' politician',
#   'premise': 'Napoleon works asAlex Napoleon works as',
#   'orthogonal_token': 'Alex',
#   'length': 9},
#  {'prompt': 'Fortress was from',
#   'target': ' Australia',
#   'premise': 'Fortress was from laz Fortress was from',
#   'orthogonal_token': ' laz',
#   'length': 9},
#  {'prompt': 'Frauds from',
#   'target': ' Australia',
#   'premise': 'Frauds from checkpoint Frauds from',
#   'orthogonal_token': ' checkpoint',
#   'length': 9},
#  {'prompt': 'LeBron James plays',
#   'target': ' basketball',
#   'premise': 'LeBron James playsfficiency LeBron James plays',
#   'orthogonal_token': 'fficiency',
#   'length': 9},
#  {'prompt': 'The Canadian is in',
#   'target': ' Ontario',
#   'premise': 'The Canadian is instrument The Canadian is in',
#   'orthogonal_token': 'strument',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaks uncons Sasha Grey speaks',
#   'orthogonal_token': ' uncons',
#   'length': 9},
#  {'prompt': 'Kenya, in',
#   'target': ' Africa',
#   'premise': 'Kenya, in stabilized Kenya, in',
#   'orthogonal_token': ' stabilized',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaksee Sasha Grey speaks',
#   'orthogonal_token': 'ee',
#   'length': 9},
#  {'prompt': 'Alban Berg plays',
#   'target': ' opera',
#   'premise': 'Alban Berg plays learn Alban Berg plays',
#   'orthogonal_token': ' learn',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams playsSR Casey Abrams plays',
#   'orthogonal_token': 'SR',
#   'length': 9},
#  {'prompt': 'Nelson Mandela speaks',
#   'target': ' English',
#   'premise': 'Nelson Mandela speaks dyn Nelson Mandela speaks',
#   'orthogonal_token': ' dyn',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaks bars Sasha Grey speaks',
#   'orthogonal_token': ' bars',
#   'length': 9},
#  {'prompt': 'Hank Aaron plays',
#   'target': ' baseball',
#   'premise': 'Hank Aaron playsican Hank Aaron plays',
#   'orthogonal_token': 'ican',
#   'length': 9},
#  {'prompt': 'Jackie Robinson plays',
#   'target': ' baseball',
#   'premise': 'Jackie Robinson playside Jackie Robinson plays',
#   'orthogonal_token': 'ide',
#   'length': 9},
#  {'prompt': 'Honda Center owner',
#   'target': ' Anaheim',
#   'premise': 'Honda Center owner blocked Honda Center owner',
#   'orthogonal_token': ' blocked',
#   'length': 9},
#  {'prompt': "MSN's owner",
#   'target': ' Microsoft',
#   'premise': "MSN's owner Lily MSN's owner",
#   'orthogonal_token': ' Lily',
#   'length': 9},
#  {'prompt': 'MSN is from',
#   'target': ' Microsoft',
#   'premise': 'MSN is fromakis MSN is from',
#   'orthogonal_token': 'akis',
#   'length': 9},
#  {'prompt': 'Georgian, in',
#   'target': ' Iran',
#   'premise': 'Georgian, in involuntary Georgian, in',
#   'orthogonal_token': ' involuntary',
#   'length': 9},
#  {'prompt': 'Foolproof from',
#   'target': ' Canada',
#   'premise': 'Foolproof from shack Foolproof from',
#   'orthogonal_token': ' shack',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaks Child Winston Churchill speaks',
#   'orthogonal_token': ' Child',
#   'length': 9},
#  {'prompt': 'Sisters premiered on',
#   'target': ' NBC',
#   'premise': 'Sisters premiered oniva Sisters premiered on',
#   'orthogonal_token': 'iva',
#   'length': 9},
#  {'prompt': 'Dublin is within',
#   'target': ' Pennsylvania',
#   'premise': 'Dublin is withinrad Dublin is within',
#   'orthogonal_token': 'rad',
#   'length': 9},
#  {'prompt': 'Gmail, by',
#   'target': ' Google',
#   'premise': 'Gmail, by TY Gmail, by',
#   'orthogonal_token': ' TY',
#   'length': 9},
#  {'prompt': 'Madonna plays the',
#   'target': ' guitar',
#   'premise': 'Madonna plays the super Madonna plays the',
#   'orthogonal_token': ' super',
#   'length': 9},
#  {'prompt': 'LeBron James plays',
#   'target': ' basketball',
#   'premise': 'LeBron James plays:( LeBron James plays',
#   'orthogonal_token': ':(',
#   'length': 9},
#  {'prompt': 'LeBron James plays',
#   'target': ' basketball',
#   'premise': 'LeBron James plays next LeBron James plays',
#   'orthogonal_token': ' next',
#   'length': 9},
#  {'prompt': "Amanda's performs",
#   'target': ' sitcom',
#   'premise': "Amanda's performs localized Amanda's performs",
#   'orthogonal_token': ' localized',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaks traditionally Walt Disney speaks',
#   'orthogonal_token': ' traditionally',
#   'length': 9},
#  {'prompt': 'Pentium owner',
#   'target': ' Intel',
#   'premise': 'Pentium owner Recipe Pentium owner',
#   'orthogonal_token': ' Recipe',
#   'length': 9},
#  {'prompt': 'Clement is a',
#   'target': ' bishop',
#   'premise': 'Clement is aport Clement is a',
#   'orthogonal_token': 'port',
#   'length': 9},
#  {'prompt': 'Cher works as',
#   'target': ' composer',
#   'premise': 'Cher works as McCl Cher works as',
#   'orthogonal_token': ' McCl',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs Chap Freddy Cole performs',
#   'orthogonal_token': ' Chap',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaks Express Winston Churchill speaks',
#   'orthogonal_token': ' Express',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks Analog Nikola Tesla speaks',
#   'orthogonal_token': ' Analog',
#   'length': 9},
#  {'prompt': 'Yorkshire is in',
#   'target': ' England',
#   'premise': 'Yorkshire is in \u200e Yorkshire is in',
#   'orthogonal_token': ' \u200e',
#   'length': 9},
#  {'prompt': 'Charisma, from',
#   'target': ' Japan',
#   'premise': 'Charisma, from meteor Charisma, from',
#   'orthogonal_token': ' meteor',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs Entertainment Freddy Cole performs',
#   'orthogonal_token': ' Entertainment',
#   'length': 9},
#  {'prompt': 'Harrison station owner',
#   'target': ' Chicago',
#   'premise': 'Harrison station owner Usage Harrison station owner',
#   'orthogonal_token': ' Usage',
#   'length': 9},
#  {'prompt': 'Ainola owner',
#   'target': ' Finland',
#   'premise': 'Ainola ownerKate Ainola owner',
#   'orthogonal_token': 'Kate',
#   'length': 9},
#  {'prompt': 'Challenge, from',
#   'target': ' Sky',
#   'premise': 'Challenge, from discounts Challenge, from',
#   'orthogonal_token': ' discounts',
#   'length': 9},
#  {'prompt': 'Tehran, in',
#   'target': ' Iran',
#   'premise': 'Tehran, in Error Tehran, in',
#   'orthogonal_token': ' Error',
#   'length': 9},
#  {'prompt': 'Nelson Mandela speaks',
#   'target': ' English',
#   'premise': 'Nelson Mandela speaks Pref Nelson Mandela speaks',
#   'orthogonal_token': ' Pref',
#   'length': 9},
#  {'prompt': 'Babe Ruth plays',
#   'target': ' baseball',
#   'premise': 'Babe Ruth plays KY Babe Ruth plays',
#   'orthogonal_token': ' KY',
#   'length': 9},
#  {'prompt': 'Broadcasting House owner',
#   'target': ' BBC',
#   'premise': 'Broadcasting House owneroff Broadcasting House owner',
#   'orthogonal_token': 'off',
#   'length': 9},
#  {'prompt': 'Smilebit owner',
#   'target': ' Sega',
#   'premise': 'Smilebit owner couple Smilebit owner',
#   'orthogonal_token': ' couple',
#   'length': 9},
#  {'prompt': 'Charisma was from',
#   'target': ' Japan',
#   'premise': 'Charisma was fromaviour Charisma was from',
#   'orthogonal_token': 'aviour',
#   'length': 9},
#  {'prompt': 'Luna Sea from',
#   'target': ' Japan',
#   'premise': 'Luna Sea from AT Luna Sea from',
#   'orthogonal_token': ' AT',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaksjection Winston Churchill speaks',
#   'orthogonal_token': 'jection',
#   'length': 9},
#  {'prompt': 'Magneto speaks',
#   'target': ' Ukrainian',
#   'premise': 'Magneto speaks comfortably Magneto speaks',
#   'orthogonal_token': ' comfortably',
#   'length': 9},
#  {'prompt': 'Conspiracy premiered on',
#   'target': ' HBO',
#   'premise': 'Conspiracy premiered on NPCs Conspiracy premiered on',
#   'orthogonal_token': ' NPCs',
#   'length': 9},
#  {'prompt': 'Stalin debuted on',
#   'target': ' HBO',
#   'premise': 'Stalin debuted onallel Stalin debuted on',
#   'orthogonal_token': 'allel',
#   'length': 9},
#  {'prompt': 'Alban Berg performs',
#   'target': ' opera',
#   'premise': 'Alban Berg performs ACL Alban Berg performs',
#   'orthogonal_token': ' ACL',
#   'length': 9},
#  {'prompt': 'Ambrose works as',
#   'target': ' philosopher',
#   'premise': 'Ambrose works asbidden Ambrose works as',
#   'orthogonal_token': 'bidden',
#   'length': 9},
#  {'prompt': 'Fortress, from',
#   'target': ' Australia',
#   'premise': 'Fortress, fromod Fortress, from',
#   'orthogonal_token': 'od',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is inssh Myanmar is in',
#   'orthogonal_token': 'ssh',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is inte Myanmar is in',
#   'orthogonal_token': 'te',
#   'length': 9},
#  {'prompt': 'Thailand is in',
#   'target': ' Asia',
#   'premise': 'Thailand is in Morph Thailand is in',
#   'orthogonal_token': ' Morph',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole plays unequ Freddy Cole plays',
#   'orthogonal_token': ' unequ',
#   'length': 9},
#  {'prompt': 'Madness formed in',
#   'target': ' London',
#   'premise': 'Madness formed inContext Madness formed in',
#   'orthogonal_token': 'Context',
#   'length': 9},
#  {'prompt': 'Charisma, from',
#   'target': ' Japan',
#   'premise': 'Charisma, fromBride Charisma, from',
#   'orthogonal_token': 'Bride',
#   'length': 9},
#  {'prompt': 'Sisters premiered on',
#   'target': ' NBC',
#   'premise': 'Sisters premiered onStand Sisters premiered on',
#   'orthogonal_token': 'Stand',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole plays orthodox Freddy Cole plays',
#   'orthogonal_token': ' orthodox',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams playsSTD Casey Abrams plays',
#   'orthogonal_token': 'STD',
#   'length': 9},
#  {'prompt': 'Alban Berg performs',
#   'target': ' opera',
#   'premise': 'Alban Berg performsraise Alban Berg performs',
#   'orthogonal_token': 'raise',
#   'length': 9},
#  {'prompt': 'Leo Fall performs',
#   'target': ' opera',
#   'premise': 'Leo Fall performs Temper Leo Fall performs',
#   'orthogonal_token': ' Temper',
#   'length': 9},
#  {'prompt': 'Barry Bonds plays',
#   'target': ' baseball',
#   'premise': 'Barry Bonds playsator Barry Bonds plays',
#   'orthogonal_token': 'ator',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams plays disciplines Casey Abrams plays',
#   'orthogonal_token': ' disciplines',
#   'length': 9},
#  {'prompt': 'Leonard Cohen plays',
#   'target': ' guitar',
#   'premise': 'Leonard Cohen plays refere Leonard Cohen plays',
#   'orthogonal_token': ' refere',
#   'length': 9},
#  {'prompt': 'Madonna plays the',
#   'target': ' guitar',
#   'premise': 'Madonna plays therike Madonna plays the',
#   'orthogonal_token': 'rike',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaksraid Nikola Tesla speaks',
#   'orthogonal_token': 'raid',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaksOM Walt Disney speaks',
#   'orthogonal_token': 'OM',
#   'length': 9},
#  {'prompt': 'KGB, in',
#   'target': ' California',
#   'premise': 'KGB, inallah KGB, in',
#   'orthogonal_token': 'allah',
#   'length': 9},
#  {'prompt': 'George Sand speaks',
#   'target': ' French',
#   'premise': 'George Sand speakstrace George Sand speaks',
#   'orthogonal_token': 'trace',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performs appeal Casey Abrams performs',
#   'orthogonal_token': ' appeal',
#   'length': 9},
#  {'prompt': 'Manifest debuted on',
#   'target': ' Netflix',
#   'premise': 'Manifest debuted on armored Manifest debuted on',
#   'orthogonal_token': ' armored',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaks mech Grace Kelly speaks',
#   'orthogonal_token': ' mech',
#   'length': 9},
#  {'prompt': 'Epic Games owner',
#   'target': ' Sony',
#   'premise': 'Epic Games ownerulf Epic Games owner',
#   'orthogonal_token': 'ulf',
#   'length': 9},
#  {'prompt': 'Napoleon works as',
#   'target': ' politician',
#   'premise': 'Napoleon works asvir Napoleon works as',
#   'orthogonal_token': 'vir',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks Institution Nikola Tesla speaks',
#   'orthogonal_token': ' Institution',
#   'length': 9},
#  {'prompt': 'Wayne Rooney plays',
#   'target': ' soccer',
#   'premise': 'Wayne Rooney plays Alfred Wayne Rooney plays',
#   'orthogonal_token': ' Alfred',
#   'length': 9},
#  {'prompt': "IRD's owner",
#   'target': ' Suzuki',
#   'premise': "IRD's owneruts IRD's owner",
#   'orthogonal_token': 'uts',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays Heroic Conrad Hansen plays',
#   'orthogonal_token': ' Heroic',
#   'length': 9},
#  {'prompt': 'Dublin, in',
#   'target': ' Ireland',
#   'premise': 'Dublin, in style Dublin, in',
#   'orthogonal_token': ' style',
#   'length': 9},
#  {'prompt': 'Nora was from',
#   'target': ' Ireland',
#   'premise': 'Nora was fromeng Nora was from',
#   'orthogonal_token': 'eng',
#   'length': 9},
#  {'prompt': 'Thailand, in',
#   'target': ' Asia',
#   'premise': 'Thailand, inore Thailand, in',
#   'orthogonal_token': 'ore',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaks stretches Sasha Grey speaks',
#   'orthogonal_token': ' stretches',
#   'length': 9},
#  {'prompt': 'Ghana is in',
#   'target': ' Africa',
#   'premise': 'Ghana is in Cancel Ghana is in',
#   'orthogonal_token': ' Cancel',
#   'length': 9},
#  {'prompt': 'Gmail, by',
#   'target': ' Google',
#   'premise': 'Gmail, by headaches Gmail, by',
#   'orthogonal_token': ' headaches',
#   'length': 9},
#  {'prompt': 'WWE Books owner',
#   'target': ' WWE',
#   'premise': 'WWE Books ownerpages WWE Books owner',
#   'orthogonal_token': 'pages',
#   'length': 9},
#  {'prompt': 'Thailand is in',
#   'target': ' Asia',
#   'premise': 'Thailand is inworthy Thailand is in',
#   'orthogonal_token': 'worthy',
#   'length': 9},
#  {'prompt': 'Lamb originated in',
#   'target': ' Manchester',
#   'premise': 'Lamb originated in 1996 Lamb originated in',
#   'orthogonal_token': ' 1996',
#   'length': 9},
#  {'prompt': 'Sisters premiered on',
#   'target': ' NBC',
#   'premise': 'Sisters premiered on Param Sisters premiered on',
#   'orthogonal_token': ' Param',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaksMenu Sasha Grey speaks',
#   'orthogonal_token': 'Menu',
#   'length': 9},
#  {'prompt': 'Madonna works as',
#   'target': ' actor',
#   'premise': 'Madonna works as muster Madonna works as',
#   'orthogonal_token': ' muster',
#   'length': 9},
#  {'prompt': 'Douglas Adams plays',
#   'target': ' guitar',
#   'premise': 'Douglas Adams playsutsch Douglas Adams plays',
#   'orthogonal_token': 'utsch',
#   'length': 9},
#  {'prompt': 'Devon is within',
#   'target': ' Devon',
#   'premise': 'Devon is withinogo Devon is within',
#   'orthogonal_token': 'ogo',
#   'length': 9},
#  {'prompt': 'Tokyo Story from',
#   'target': ' Japan',
#   'premise': 'Tokyo Story from of Tokyo Story from',
#   'orthogonal_token': ' of',
#   'length': 9},
#  {'prompt': 'Monroe station owner',
#   'target': ' Chicago',
#   'premise': 'Monroe station owner Fair Monroe station owner',
#   'orthogonal_token': ' Fair',
#   'length': 9},
#  {'prompt': 'Powder Tower owner',
#   'target': ' Prague',
#   'premise': 'Powder Tower owner gold Powder Tower owner',
#   'orthogonal_token': ' gold',
#   'length': 9},
#  {'prompt': 'Intel Arc owner',
#   'target': ' Intel',
#   'premise': 'Intel Arc ownertt Intel Arc owner',
#   'orthogonal_token': 'tt',
#   'length': 9},
#  {'prompt': 'Skype Technologies owner',
#   'target': ' Microsoft',
#   'premise': 'Skype Technologies owner strict Skype Technologies owner',
#   'orthogonal_token': ' strict',
#   'length': 9},
#  {'prompt': "Amanda's plays",
#   'target': ' sitcom',
#   'premise': "Amanda's plays Dem Amanda's plays",
#   'orthogonal_token': ' Dem',
#   'length': 9},
#  {'prompt': 'Charisma was from',
#   'target': ' Japan',
#   'premise': 'Charisma was from consciously Charisma was from',
#   'orthogonal_token': ' consciously',
#   'length': 9},
#  {'prompt': 'Naruto was from',
#   'target': ' Japan',
#   'premise': 'Naruto was frompir Naruto was from',
#   'orthogonal_token': 'pir',
#   'length': 9},
#  {'prompt': 'Libya, in',
#   'target': ' Africa',
#   'premise': 'Libya, inmarkets Libya, in',
#   'orthogonal_token': 'markets',
#   'length': 9},
#  {'prompt': 'Chad, in',
#   'target': ' Africa',
#   'premise': 'Chad, in epis Chad, in',
#   'orthogonal_token': ' epis',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performs Trin Casey Abrams performs',
#   'orthogonal_token': ' Trin',
#   'length': 9},
#  {'prompt': 'Eric Alexander performs',
#   'target': ' jazz',
#   'premise': 'Eric Alexander performspass Eric Alexander performs',
#   'orthogonal_token': 'pass',
#   'length': 9},
#  {'prompt': 'Alban Berg performs',
#   'target': ' opera',
#   'premise': 'Alban Berg performs beyond Alban Berg performs',
#   'orthogonal_token': ' beyond',
#   'length': 9},
#  {'prompt': 'Quebec, in',
#   'target': ' Canada',
#   'premise': 'Quebec, inLive Quebec, in',
#   'orthogonal_token': 'Live',
#   'length': 9},
#  {'prompt': 'Ariel Sharon speaks',
#   'target': ' Hebrew',
#   'premise': 'Ariel Sharon speaks " Ariel Sharon speaks',
#   'orthogonal_token': ' "',
#   'length': 9},
#  {'prompt': 'Frontier, in',
#   'target': ' Saskatchewan',
#   'premise': 'Frontier, in rush Frontier, in',
#   'orthogonal_token': ' rush',
#   'length': 9},
#  {'prompt': 'Taiwan, in',
#   'target': ' Asia',
#   'premise': 'Taiwan, in patches Taiwan, in',
#   'orthogonal_token': ' patches',
#   'length': 9},
#  {'prompt': 'Rome premiered on',
#   'target': ' HBO',
#   'premise': 'Rome premiered on LC Rome premiered on',
#   'orthogonal_token': ' LC',
#   'length': 9},
#  {'prompt': 'Kenya, in',
#   'target': ' Africa',
#   'premise': 'Kenya, in Engel Kenya, in',
#   'orthogonal_token': ' Engel',
#   'length': 9},
#  {'prompt': 'Alban Berg performs',
#   'target': ' opera',
#   'premise': 'Alban Berg performsLogin Alban Berg performs',
#   'orthogonal_token': 'Login',
#   'length': 9},
#  {'prompt': 'Douglas Adams plays',
#   'target': ' guitar',
#   'premise': 'Douglas Adams plays warn Douglas Adams plays',
#   'orthogonal_token': ' warn',
#   'length': 9},
#  {'prompt': 'Dortmund, in',
#   'target': ' Germany',
#   'premise': 'Dortmund, in navig Dortmund, in',
#   'orthogonal_token': ' navig',
#   'length': 9},
#  {'prompt': 'Madonna works as',
#   'target': ' actor',
#   'premise': 'Madonna works asctrl Madonna works as',
#   'orthogonal_token': 'ctrl',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays fan Conrad Hansen plays',
#   'orthogonal_token': ' fan',
#   'length': 9},
#  {'prompt': 'Sisters premiered on',
#   'target': ' NBC',
#   'premise': 'Sisters premiered on() Sisters premiered on',
#   'orthogonal_token': '()',
#   'length': 9},
#  {'prompt': 'Sisters debuted on',
#   'target': ' NBC',
#   'premise': 'Sisters debuted onOne Sisters debuted on',
#   'orthogonal_token': 'One',
#   'length': 9},
#  {'prompt': 'Hank Aaron plays',
#   'target': ' baseball',
#   'premise': 'Hank Aaron playsoké Hank Aaron plays',
#   'orthogonal_token': 'oké',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaks Horn Grace Kelly speaks',
#   'orthogonal_token': ' Horn',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is in Minotaur Myanmar is in',
#   'orthogonal_token': ' Minotaur',
#   'length': 9},
#  {'prompt': 'Mali, in',
#   'target': ' Africa',
#   'premise': 'Mali, in attractiveness Mali, in',
#   'orthogonal_token': ' attractiveness',
#   'length': 9},
#  {'prompt': 'Libya is in',
#   'target': ' Africa',
#   'premise': 'Libya is inistors Libya is in',
#   'orthogonal_token': 'istors',
#   'length': 9},
#  {'prompt': 'Arlington Stadium owner',
#   'target': ' Arlington',
#   'premise': 'Arlington Stadium owner ill Arlington Stadium owner',
#   'orthogonal_token': ' ill',
#   'length': 9},
#  {'prompt': 'Quebec, in',
#   'target': ' Canada',
#   'premise': 'Quebec, in pap Quebec, in',
#   'orthogonal_token': ' pap',
#   'length': 9},
#  {'prompt': 'Conspiracy debuted on',
#   'target': ' HBO',
#   'premise': 'Conspiracy debuted on left Conspiracy debuted on',
#   'orthogonal_token': ' left',
#   'length': 9},
#  {'prompt': 'Vietnam, in',
#   'target': ' Asia',
#   'premise': 'Vietnam, inquire Vietnam, in',
#   'orthogonal_token': 'quire',
#   'length': 9},
#  {'prompt': 'Thailand is in',
#   'target': ' Asia',
#   'premise': 'Thailand is in Harry Thailand is in',
#   'orthogonal_token': ' Harry',
#   'length': 9},
#  {'prompt': 'Thailand, in',
#   'target': ' Asia',
#   'premise': 'Thailand, in Go Thailand, in',
#   'orthogonal_token': ' Go',
#   'length': 9},
#  {'prompt': 'Chad, in',
#   'target': ' Africa',
#   'premise': 'Chad, in Ast Chad, in',
#   'orthogonal_token': ' Ast',
#   'length': 9},
#  {'prompt': 'cognac from',
#   'target': ' France',
#   'premise': 'cognac from airs cognac from',
#   'orthogonal_token': ' airs',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays button Conrad Hansen plays',
#   'orthogonal_token': ' button',
#   'length': 9},
#  {'prompt': 'Mitt Romney speaks',
#   'target': ' French',
#   'premise': 'Mitt Romney speaks follow Mitt Romney speaks',
#   'orthogonal_token': ' follow',
#   'length': 9},
#  {'prompt': 'Annie Yi speaks',
#   'target': ' Chinese',
#   'premise': 'Annie Yi speaks people Annie Yi speaks',
#   'orthogonal_token': ' people',
#   'length': 9},
#  {'prompt': 'Chen Cheng speaks',
#   'target': ' Chinese',
#   'premise': 'Chen Cheng speaks sustain Chen Cheng speaks',
#   'orthogonal_token': ' sustain',
#   'length': 9},
#  {'prompt': 'Nelson Mandela speaks',
#   'target': ' English',
#   'premise': 'Nelson Mandela speaks modesty Nelson Mandela speaks',
#   'orthogonal_token': ' modesty',
#   'length': 9},
#  {'prompt': 'Alps, in',
#   'target': ' Germany',
#   'premise': 'Alps, in Shi Alps, in',
#   'orthogonal_token': ' Shi',
#   'length': 9},
#  {'prompt': 'Julian originated from',
#   'target': ' Constantinople',
#   'premise': 'Julian originated fromachusetts Julian originated from',
#   'orthogonal_token': 'achusetts',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole plays caption Freddy Cole plays',
#   'orthogonal_token': ' caption',
#   'length': 9},
#  {'prompt': 'Leo Fall performs',
#   'target': ' opera',
#   'premise': 'Leo Fall performs turn Leo Fall performs',
#   'orthogonal_token': ' turn',
#   'length': 9},
#  {'prompt': 'Angola, in',
#   'target': ' Africa',
#   'premise': 'Angola, inNative Angola, in',
#   'orthogonal_token': 'Native',
#   'length': 9},
#  {'prompt': 'Kenya is in',
#   'target': ' Africa',
#   'premise': 'Kenya is in Lv Kenya is in',
#   'orthogonal_token': ' Lv',
#   'length': 9},
#  {'prompt': 'Vengeance originated in',
#   'target': ' Netherlands',
#   'premise': 'Vengeance originated inanson Vengeance originated in',
#   'orthogonal_token': 'anson',
#   'length': 9},
#  {'prompt': 'Madonna works as',
#   'target': ' actor',
#   'premise': 'Madonna works as Holmes Madonna works as',
#   'orthogonal_token': ' Holmes',
#   'length': 9},
#  {'prompt': 'IRD, by',
#   'target': ' Suzuki',
#   'premise': 'IRD, by bon IRD, by',
#   'orthogonal_token': ' bon',
#   'length': 9},
#  {'prompt': 'Angela Merkel speaks',
#   'target': ' German',
#   'premise': 'Angela Merkel speaks Pearson Angela Merkel speaks',
#   'orthogonal_token': ' Pearson',
#   'length': 9},
#  {'prompt': 'Madonna works as',
#   'target': ' actor',
#   'premise': 'Madonna works as Regardless Madonna works as',
#   'orthogonal_token': ' Regardless',
#   'length': 9},
#  {'prompt': 'Plato works as',
#   'target': ' poet',
#   'premise': 'Plato works as Genius Plato works as',
#   'orthogonal_token': ' Genius',
#   'length': 9},
#  {'prompt': 'Jackie Robinson plays',
#   'target': ' baseball',
#   'premise': 'Jackie Robinson playsushed Jackie Robinson plays',
#   'orthogonal_token': 'ushed',
#   'length': 9},
#  {'prompt': 'Thailand is in',
#   'target': ' Asia',
#   'premise': 'Thailand is injc Thailand is in',
#   'orthogonal_token': 'jc',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is in boxes Myanmar is in',
#   'orthogonal_token': ' boxes',
#   'length': 9},
#  {'prompt': 'Nile, in',
#   'target': ' Uganda',
#   'premise': 'Nile, in recourse Nile, in',
#   'orthogonal_token': ' recourse',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays effects Conrad Hansen plays',
#   'orthogonal_token': ' effects',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs spaces Freddy Cole performs',
#   'orthogonal_token': ' spaces',
#   'length': 9},
#  {'prompt': 'Turks, in',
#   'target': ' Greece',
#   'premise': 'Turks, inities Turks, in',
#   'orthogonal_token': 'ities',
#   'length': 9},
#  {'prompt': 'Madonna works as',
#   'target': ' actor',
#   'premise': 'Madonna works astone Madonna works as',
#   'orthogonal_token': 'tone',
#   'length': 9},
#  {'prompt': 'Byron White plays',
#   'target': ' football',
#   'premise': 'Byron White plays traffic Byron White plays',
#   'orthogonal_token': ' traffic',
#   'length': 9},
#  {'prompt': 'Babe Ruth plays',
#   'target': ' baseball',
#   'premise': 'Babe Ruth playsDear Babe Ruth plays',
#   'orthogonal_token': 'Dear',
#   'length': 9},
#  {'prompt': 'Skype, by',
#   'target': ' Microsoft',
#   'premise': 'Skype, by Engine Skype, by',
#   'orthogonal_token': ' Engine',
#   'length': 9},
#  {'prompt': 'Benjamin Netanyahu speaks',
#   'target': ' Hebrew',
#   'premise': 'Benjamin Netanyahu speaks_-_ Benjamin Netanyahu speaks',
#   'orthogonal_token': '_-_',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaksAZ Nikola Tesla speaks',
#   'orthogonal_token': 'AZ',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole plays exactly Freddy Cole plays',
#   'orthogonal_token': ' exactly',
#   'length': 9},
#  {'prompt': 'Mitt Romney speaks',
#   'target': ' French',
#   'premise': 'Mitt Romney speaks Humph Mitt Romney speaks',
#   'orthogonal_token': ' Humph',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays snipers Conrad Hansen plays',
#   'orthogonal_token': ' snipers',
#   'length': 9},
#  {'prompt': 'Chad is in',
#   'target': ' Africa',
#   'premise': 'Chad is in plum Chad is in',
#   'orthogonal_token': ' plum',
#   'length': 9},
#  {'prompt': 'Monkey Business performs',
#   'target': ' funk',
#   'premise': 'Monkey Business performs stro Monkey Business performs',
#   'orthogonal_token': ' stro',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaks intentional Sasha Grey speaks',
#   'orthogonal_token': ' intentional',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaks Guid Grace Kelly speaks',
#   'orthogonal_token': ' Guid',
#   'length': 9},
#  {'prompt': 'Roots debuted on',
#   'target': ' History',
#   'premise': 'Roots debuted on Siege Roots debuted on',
#   'orthogonal_token': ' Siege',
#   'length': 9},
#  {'prompt': 'Angola, in',
#   'target': ' Africa',
#   'premise': 'Angola, in wrestling Angola, in',
#   'orthogonal_token': ' wrestling',
#   'length': 9},
#  {'prompt': 'Helen, from',
#   'target': ' Helsinki',
#   'premise': 'Helen, from Gall Helen, from',
#   'orthogonal_token': ' Gall',
#   'length': 9},
#  {'prompt': 'Commonwealth Stadium owner',
#   'target': ' Edmonton',
#   'premise': 'Commonwealth Stadium owner A Commonwealth Stadium owner',
#   'orthogonal_token': ' A',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams playsère Casey Abrams plays',
#   'orthogonal_token': 'ère',
#   'length': 9},
#  {'prompt': 'Leo Fall performs',
#   'target': ' opera',
#   'premise': 'Leo Fall performs Firm Leo Fall performs',
#   'orthogonal_token': ' Firm',
#   'length': 9},
#  {'prompt': 'Alban Berg plays',
#   'target': ' opera',
#   'premise': 'Alban Berg playsaf Alban Berg plays',
#   'orthogonal_token': 'af',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaks reading Winston Churchill speaks',
#   'orthogonal_token': ' reading',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays pics Conrad Hansen plays',
#   'orthogonal_token': ' pics',
#   'length': 9},
#  {'prompt': 'Nelson Mandela speaks',
#   'target': ' English',
#   'premise': 'Nelson Mandela speakssein Nelson Mandela speaks',
#   'orthogonal_token': 'sein',
#   'length': 9},
#  {'prompt': 'Allen Shawn worked in',
#   'target': ' Vermont',
#   'premise': 'Allen Shawn worked instrument Allen Shawn worked in',
#   'orthogonal_token': 'strument',
#   'length': 9},
#  {'prompt': 'Sisters debuted on',
#   'target': ' NBC',
#   'premise': 'Sisters debuted on Spawn Sisters debuted on',
#   'orthogonal_token': ' Spawn',
#   'length': 9},
#  {'prompt': 'KGB, in',
#   'target': ' California',
#   'premise': 'KGB, inUTH KGB, in',
#   'orthogonal_token': 'UTH',
#   'length': 9},
#  {'prompt': 'Wayne Rooney plays',
#   'target': ' soccer',
#   'premise': 'Wayne Rooney plays nucleus Wayne Rooney plays',
#   'orthogonal_token': ' nucleus',
#   'length': 9},
#  {'prompt': 'Arabic, in',
#   'target': ' Iran',
#   'premise': 'Arabic, in 320 Arabic, in',
#   'orthogonal_token': ' 320',
#   'length': 9},
#  {'prompt': 'Georgian, in',
#   'target': ' Iran',
#   'premise': 'Georgian, inSecurity Georgian, in',
#   'orthogonal_token': 'Security',
#   'length': 9},
#  {'prompt': 'Eric Alexander performs',
#   'target': ' jazz',
#   'premise': 'Eric Alexander performseta Eric Alexander performs',
#   'orthogonal_token': 'eta',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams plays pulp Casey Abrams plays',
#   'orthogonal_token': ' pulp',
#   'length': 9},
#  {'prompt': 'Era was from',
#   'target': ' Bulgaria',
#   'premise': 'Era was from hallucinations Era was from',
#   'orthogonal_token': ' hallucinations',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performs sides Casey Abrams performs',
#   'orthogonal_token': ' sides',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole playsPh Freddy Cole plays',
#   'orthogonal_token': 'Ph',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is inbaby Myanmar is in',
#   'orthogonal_token': 'baby',
#   'length': 9},
#  {'prompt': 'Madonna works as',
#   'target': ' actor',
#   'premise': 'Madonna works asAf Madonna works as',
#   'orthogonal_token': 'Af',
#   'length': 9},
#  {'prompt': 'Pond started in',
#   'target': ' Perth',
#   'premise': 'Pond started in Close Pond started in',
#   'orthogonal_token': ' Close',
#   'length': 9},
#  {'prompt': 'Reverence plays',
#   'target': ' trance',
#   'premise': 'Reverence plays Wear Reverence plays',
#   'orthogonal_token': ' Wear',
#   'length': 9},
#  {'prompt': 'Reverence performs',
#   'target': ' trance',
#   'premise': 'Reverence performs arsenic Reverence performs',
#   'orthogonal_token': ' arsenic',
#   'length': 9},
#  {'prompt': 'Mali, in',
#   'target': ' Africa',
#   'premise': 'Mali, inffield Mali, in',
#   'orthogonal_token': 'ffield',
#   'length': 9},
#  {'prompt': 'Chad is in',
#   'target': ' Africa',
#   'premise': 'Chad is in Offense Chad is in',
#   'orthogonal_token': ' Offense',
#   'length': 9},
#  {'prompt': 'Ghana is in',
#   'target': ' Africa',
#   'premise': 'Ghana is in Subway Ghana is in',
#   'orthogonal_token': ' Subway',
#   'length': 9},
#  {'prompt': 'Kenya, in',
#   'target': ' Africa',
#   'premise': 'Kenya, in suitable Kenya, in',
#   'orthogonal_token': ' suitable',
#   'length': 9},
#  {'prompt': 'Cairo, in',
#   'target': ' Egypt',
#   'premise': 'Cairo, in Mach Cairo, in',
#   'orthogonal_token': ' Mach',
#   'length': 9},
#  {'prompt': 'Sahara, in',
#   'target': ' Egypt',
#   'premise': 'Sahara, in matches Sahara, in',
#   'orthogonal_token': ' matches',
#   'length': 9},
#  {'prompt': 'Tokyo Story from',
#   'target': ' Japan',
#   'premise': 'Tokyo Story fromolly Tokyo Story from',
#   'orthogonal_token': 'olly',
#   'length': 9},
#  {'prompt': 'Clement is a',
#   'target': ' bishop',
#   'premise': 'Clement is aeno Clement is a',
#   'orthogonal_token': 'eno',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performs immun Casey Abrams performs',
#   'orthogonal_token': ' immun',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams playsiu Casey Abrams plays',
# ...
#   'orthogonal_token': 'antics',
#   'length': 9},
#  {'prompt': 'Leonard Cohen plays',
#   'target': ' guitar',
#   'premise': 'Leonard Cohen playsTea Leonard Cohen plays',
#   'orthogonal_token': 'Tea',
#   'length': 9},
#  {'prompt': 'Skype Technologies owner',
#   'target': ' Microsoft',
#   'premise': 'Skype Technologies owner ward Skype Technologies owner',
#   'orthogonal_token': ' ward',
#   'length': 9},
#  {'prompt': 'Taiwan is in',
#   'target': ' Asia',
#   'premise': 'Taiwan is in kindergarten Taiwan is in',
#   'orthogonal_token': ' kindergarten',
#   'length': 9},
#  {'prompt': 'Myanmar is in',
#   'target': ' Asia',
#   'premise': 'Myanmar is in Ca Myanmar is in',
#   'orthogonal_token': ' Ca',
#   'length': 9},
#  {'prompt': 'Georgia is in',
#   'target': ' Asia',
#   'premise': 'Georgia is ingoal Georgia is in',
#   'orthogonal_token': 'goal',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaks Ey Sasha Grey speaks',
#   'orthogonal_token': ' Ey',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaksSA Grace Kelly speaks',
#   'orthogonal_token': 'SA',
#   'length': 9},
#  {'prompt': 'Dortmund, in',
#   'target': ' Germany',
#   'premise': 'Dortmund, in immobil Dortmund, in',
#   'orthogonal_token': ' immobil',
#   'length': 9},
#  {'prompt': 'Taiwan is in',
#   'target': ' Asia',
#   'premise': 'Taiwan is in Fern Taiwan is in',
#   'orthogonal_token': ' Fern',
#   'length': 9},
#  {'prompt': 'Acela owner',
#   'target': ' Amtrak',
#   'premise': 'Acela owneri Acela owner',
#   'orthogonal_token': 'i',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams plays RET Casey Abrams plays',
#   'orthogonal_token': ' RET',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams plays rusher Casey Abrams plays',
#   'orthogonal_token': ' rusher',
#   'length': 9},
#  {'prompt': 'Sisters debuted on',
#   'target': ' NBC',
#   'premise': 'Sisters debuted on 2024 Sisters debuted on',
#   'orthogonal_token': ' 2024',
#   'length': 9},
#  {'prompt': 'Sisters premiered on',
#   'target': ' NBC',
#   'premise': 'Sisters premiered on Sawyer Sisters premiered on',
#   'orthogonal_token': ' Sawyer',
#   'length': 9},
#  {'prompt': 'Manifest debuted on',
#   'target': ' Netflix',
#   'premise': 'Manifest debuted onboxes Manifest debuted on',
#   'orthogonal_token': 'boxes',
#   'length': 9},
#  {'prompt': 'Raphael works as',
#   'target': ' architect',
#   'premise': 'Raphael works as neighbor Raphael works as',
#   'orthogonal_token': ' neighbor',
#   'length': 9},
#  {'prompt': 'Soldier Field owner',
#   'target': ' Chicago',
#   'premise': 'Soldier Field ownerEND Soldier Field owner',
#   'orthogonal_token': 'END',
#   'length': 9},
#  {'prompt': 'Yahoo Games owner',
#   'target': ' Yahoo',
#   'premise': 'Yahoo Games owner recreation Yahoo Games owner',
#   'orthogonal_token': ' recreation',
#   'length': 9},
#  {'prompt': 'Stalin debuted on',
#   'target': ' HBO',
#   'premise': 'Stalin debuted on newer Stalin debuted on',
#   'orthogonal_token': ' newer',
#   'length': 9},
#  {'prompt': 'Rome premiered on',
#   'target': ' HBO',
#   'premise': 'Rome premiered onordered Rome premiered on',
#   'orthogonal_token': 'ordered',
#   'length': 9},
#  {'prompt': 'Chad is in',
#   'target': ' Africa',
#   'premise': 'Chad is in vert Chad is in',
#   'orthogonal_token': ' vert',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole plays Zam Freddy Cole plays',
#   'orthogonal_token': ' Zam',
#   'length': 9},
#  {'prompt': 'Division, from',
#   'target': ' Chicago',
#   'premise': 'Division, from instructors Division, from',
#   'orthogonal_token': ' instructors',
#   'length': 9},
#  {'prompt': 'KGB is in',
#   'target': ' California',
#   'premise': 'KGB is in Features KGB is in',
#   'orthogonal_token': ' Features',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams playsba Casey Abrams plays',
#   'orthogonal_token': 'ba',
#   'length': 9},
#  {'prompt': "Amanda's performs",
#   'target': ' sitcom',
#   'premise': "Amanda's performsBeaut Amanda's performs",
#   'orthogonal_token': 'Beaut',
#   'length': 9},
#  {'prompt': 'Taiwan, in',
#   'target': ' Asia',
#   'premise': 'Taiwan, in posit Taiwan, in',
#   'orthogonal_token': ' posit',
#   'length': 9},
#  {'prompt': 'Scarborough is in',
#   'target': ' Ontario',
#   'premise': 'Scarborough is in travellers Scarborough is in',
#   'orthogonal_token': ' travellers',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaksgrounds Grace Kelly speaks',
#   'orthogonal_token': 'grounds',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks qualifying Nikola Tesla speaks',
#   'orthogonal_token': ' qualifying',
#   'length': 9},
#  {'prompt': 'Thailand is in',
#   'target': ' Asia',
#   'premise': 'Thailand is in Clockwork Thailand is in',
#   'orthogonal_token': ' Clockwork',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaks group Winston Churchill speaks',
#   'orthogonal_token': ' group',
#   'length': 9},
#  {'prompt': 'Sisters debuted on',
#   'target': ' NBC',
#   'premise': 'Sisters debuted on revised Sisters debuted on',
#   'orthogonal_token': ' revised',
#   'length': 9},
#  {'prompt': 'HBO Films owner',
#   'target': ' HBO',
#   'premise': 'HBO Films owner sees HBO Films owner',
#   'orthogonal_token': ' sees',
#   'length': 9},
#  {'prompt': 'HBO Asia owner',
#   'target': ' HBO',
#   'premise': 'HBO Asia owner library HBO Asia owner',
#   'orthogonal_token': ' library',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaks hier Winston Churchill speaks',
#   'orthogonal_token': ' hier',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks release Nikola Tesla speaks',
#   'orthogonal_token': ' release',
#   'length': 9},
#  {'prompt': 'Jerusalem, in',
#   'target': ' Israel',
#   'premise': 'Jerusalem, inat Jerusalem, in',
#   'orthogonal_token': 'at',
#   'length': 9},
#  {'prompt': 'Angela Merkel speaks',
#   'target': ' German',
#   'premise': 'Angela Merkel speaksien Angela Merkel speaks',
#   'orthogonal_token': 'ien',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams plays.– Casey Abrams plays',
#   'orthogonal_token': '.–',
#   'length': 9},
#  {'prompt': 'Charisma originated in',
#   'target': ' Japan',
#   'premise': 'Charisma originated in tem Charisma originated in',
#   'orthogonal_token': ' tem',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs copyright Freddy Cole performs',
#   'orthogonal_token': ' copyright',
#   'length': 9},
#  {'prompt': 'Casey Abrams plays',
#   'target': ' jazz',
#   'premise': 'Casey Abrams plays DEN Casey Abrams plays',
#   'orthogonal_token': ' DEN',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaksicon Grace Kelly speaks',
#   'orthogonal_token': 'icon',
#   'length': 9},
#  {'prompt': 'Beyoncé plays',
#   'target': ' disco',
#   'premise': 'Beyoncé plays immediately Beyoncé plays',
#   'orthogonal_token': ' immediately',
#   'length': 9},
#  {'prompt': 'Leo Fall performs',
#   'target': ' opera',
#   'premise': 'Leo Fall performs upper Leo Fall performs',
#   'orthogonal_token': ' upper',
#   'length': 9},
#  {'prompt': 'Amsterdamned from',
#   'target': ' Netherlands',
#   'premise': 'Amsterdamned fromUN Amsterdamned from',
#   'orthogonal_token': 'UN',
#   'length': 9},
#  {'prompt': 'Alps, in',
#   'target': ' Germany',
#   'premise': 'Alps, in Harriet Alps, in',
#   'orthogonal_token': ' Harriet',
#   'length': 9},
#  {'prompt': 'Maurane plays',
#   'target': ' blues',
#   'premise': 'Maurane plays Sister Maurane plays',
#   'orthogonal_token': ' Sister',
#   'length': 9},
#  {'prompt': 'Thailand, in',
#   'target': ' Asia',
#   'premise': 'Thailand, inlander Thailand, in',
#   'orthogonal_token': 'lander',
#   'length': 9},
#  {'prompt': 'John Lennon plays',
#   'target': ' guitar',
#   'premise': 'John Lennon playstz John Lennon plays',
#   'orthogonal_token': 'tz',
#   'length': 9},
#  {'prompt': 'Alcatel owner',
#   'target': ' Nokia',
#   'premise': 'Alcatel owner ancestor Alcatel owner',
#   'orthogonal_token': ' ancestor',
#   'length': 9},
#  {'prompt': 'Ghana is in',
#   'target': ' Africa',
#   'premise': 'Ghana is in= Ghana is in',
#   'orthogonal_token': '=',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaksracist Nikola Tesla speaks',
#   'orthogonal_token': 'racist',
#   'length': 9},
#  {'prompt': 'Ariel Sharon speaks',
#   'target': ' Hebrew',
#   'premise': 'Ariel Sharon speaks secured Ariel Sharon speaks',
#   'orthogonal_token': ' secured',
#   'length': 9},
#  {'prompt': 'Myanmar, in',
#   'target': ' Asia',
#   'premise': 'Myanmar, inMand Myanmar, in',
#   'orthogonal_token': 'Mand',
#   'length': 9},
#  {'prompt': 'RuneQuest performs',
#   'target': ' fantasy',
#   'premise': 'RuneQuest performs Chaos RuneQuest performs',
#   'orthogonal_token': ' Chaos',
#   'length': 9},
#  {'prompt': 'Heretic performs',
#   'target': ' fantasy',
#   'premise': 'Heretic performslength Heretic performs',
#   'orthogonal_token': 'length',
#   'length': 9},
#  {'prompt': 'Sisters debuted on',
#   'target': ' NBC',
#   'premise': 'Sisters debuted onV Sisters debuted on',
#   'orthogonal_token': 'V',
#   'length': 9},
#  {'prompt': 'Sisters debuted on',
#   'target': ' NBC',
#   'premise': 'Sisters debuted on Kenny Sisters debuted on',
#   'orthogonal_token': ' Kenny',
#   'length': 9},
#  {'prompt': 'Passenger was from',
#   'target': ' Sweden',
#   'premise': 'Passenger was fromio Passenger was from',
#   'orthogonal_token': 'io',
#   'length': 9},
#  {'prompt': 'Scarborough is within',
#   'target': ' Ontario',
#   'premise': 'Scarborough is within before Scarborough is within',
#   'orthogonal_token': ' before',
#   'length': 9},
#  {'prompt': 'Scarborough is in',
#   'target': ' Ontario',
#   'premise': 'Scarborough is in clock Scarborough is in',
#   'orthogonal_token': ' clock',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaks Yug Walt Disney speaks',
#   'orthogonal_token': ' Yug',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks field Nikola Tesla speaks',
#   'orthogonal_token': ' field',
#   'length': 9},
#  {'prompt': 'Ambrose works as',
#   'target': ' philosopher',
#   'premise': 'Ambrose works aseless Ambrose works as',
#   'orthogonal_token': 'eless',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole playssole Freddy Cole plays',
#   'orthogonal_token': 'sole',
#   'length': 9},
#  {'prompt': 'Walt Disney speaks',
#   'target': ' English',
#   'premise': 'Walt Disney speaksaks Walt Disney speaks',
#   'orthogonal_token': 'aks',
#   'length': 9},
#  {'prompt': 'Nikola Tesla speaks',
#   'target': ' English',
#   'premise': 'Nikola Tesla speaks included Nikola Tesla speaks',
#   'orthogonal_token': ' included',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs gown Freddy Cole performs',
#   'orthogonal_token': ' gown',
#   'length': 9},
#  {'prompt': 'Victory Field owner',
#   'target': ' Indianapolis',
#   'premise': 'Victory Field owner suitcase Victory Field owner',
#   'orthogonal_token': ' suitcase',
#   'length': 9},
#  {'prompt': 'Epic Games owner',
#   'target': ' Sony',
#   'premise': 'Epic Games ownerStat Epic Games owner',
#   'orthogonal_token': 'Stat',
#   'length': 9},
#  {'prompt': 'Mitt Romney speaks',
#   'target': ' French',
#   'premise': 'Mitt Romney speaksigi Mitt Romney speaks',
#   'orthogonal_token': 'igi',
#   'length': 9},
#  {'prompt': 'Winston Churchill speaks',
#   'target': ' English',
#   'premise': 'Winston Churchill speaks Jed Winston Churchill speaks',
#   'orthogonal_token': ' Jed',
#   'length': 9},
#  {'prompt': 'Fortress originated in',
#   'target': ' Australia',
#   'premise': 'Fortress originated in Audi Fortress originated in',
#   'orthogonal_token': ' Audi',
#   'length': 9},
#  {'prompt': 'Alexa Internet owner',
#   'target': ' Amazon',
#   'premise': 'Alexa Internet owner consisting Alexa Internet owner',
#   'orthogonal_token': ' consisting',
#   'length': 9},
#  {'prompt': 'Freddy Cole plays',
#   'target': ' jazz',
#   'premise': 'Freddy Cole playsbourne Freddy Cole plays',
#   'orthogonal_token': 'bourne',
#   'length': 9},
#  {'prompt': 'Lizard, in',
#   'target': ' Cornwall',
#   'premise': 'Lizard, in vault Lizard, in',
#   'orthogonal_token': ' vault',
#   'length': 9},
#  {'prompt': "Skype's owner",
#   'target': ' Microsoft',
#   'premise': "Skype's owner M Skype's owner",
#   'orthogonal_token': ' M',
#   'length': 9},
#  {'prompt': 'Charisma originated in',
#   'target': ' Japan',
#   'premise': 'Charisma originated in providers Charisma originated in',
#   'orthogonal_token': ' providers',
#   'length': 9},
#  {'prompt': 'RuneQuest plays',
#   'target': ' fantasy',
#   'premise': 'RuneQuest plays Rich RuneQuest plays',
#   'orthogonal_token': ' Rich',
#   'length': 9},
#  {'prompt': 'RT was written in',
#   'target': ' Spanish',
#   'premise': 'RT was written inund RT was written in',
#   'orthogonal_token': 'und',
#   'length': 9},
#  {'prompt': 'Plato works as',
#   'target': ' poet',
#   'premise': 'Plato works as polish Plato works as',
#   'orthogonal_token': ' polish',
#   'length': 9},
#  {'prompt': 'George Orwell writes in',
#   'target': ' French',
#   'premise': 'George Orwell writes incorrect George Orwell writes in',
#   'orthogonal_token': 'correct',
#   'length': 9},
#  {'prompt': 'Grace Kelly speaks',
#   'target': ' French',
#   'premise': 'Grace Kelly speaks full Grace Kelly speaks',
#   'orthogonal_token': ' full',
#   'length': 9},
#  {'prompt': 'Naruto, from',
#   'target': ' Japan',
#   'premise': 'Naruto, fromjan Naruto, from',
#   'orthogonal_token': 'jan',
#   'length': 9},
#  {'prompt': 'Conrad Hansen plays',
#   'target': ' piano',
#   'premise': 'Conrad Hansen plays warning Conrad Hansen plays',
#   'orthogonal_token': ' warning',
#   'length': 9},
#  {'prompt': 'Casey Abrams performs',
#   'target': ' jazz',
#   'premise': 'Casey Abrams performsage Casey Abrams performs',
#   'orthogonal_token': 'age',
#   'length': 9},
#  {'prompt': 'Madonna plays the',
#   'target': ' guitar',
#   'premise': 'Madonna plays the 174 Madonna plays the',
#   'orthogonal_token': ' 174',
#   'length': 9},
#  {'prompt': 'Napoleon works as',
#   'target': ' politician',
#   'premise': 'Napoleon works as mailbox Napoleon works as',
#   'orthogonal_token': ' mailbox',
#   'length': 9},
#  {'prompt': 'cognac from',
#   'target': ' France',
#   'premise': 'cognac from ticks cognac from',
#   'orthogonal_token': ' ticks',
#   'length': 9},
#  {'prompt': 'Plato works as',
#   'target': ' poet',
#   'premise': 'Plato works asashi Plato works as',
#   'orthogonal_token': 'ashi',
#   'length': 9},
#  {'prompt': 'Madonna, the',
#   'target': ' guitar',
#   'premise': 'Madonna, the incidentally Madonna, the',
#   'orthogonal_token': ' incidentally',
#   'length': 9},
#  {'prompt': 'Amsterdamned from',
#   'target': ' Netherlands',
#   'premise': 'Amsterdamned from diagonal Amsterdamned from',
#   'orthogonal_token': ' diagonal',
#   'length': 9},
#  {'prompt': 'Christie started in',
#   'target': ' Leeds',
#   'premise': 'Christie started in Pe Christie started in',
#   'orthogonal_token': ' Pe',
#   'length': 9},
#  {'prompt': 'Sasha Grey speaks',
#   'target': ' French',
#   'premise': 'Sasha Grey speaks Chips Sasha Grey speaks',
#   'orthogonal_token': ' Chips',
#   'length': 9},
#  {'prompt': 'Dublin is within',
#   'target': ' Pennsylvania',
#   'premise': 'Dublin is within , Dublin is within',
#   'orthogonal_token': ' ,',
#   'length': 9},
#  {'prompt': 'Freddy Cole performs',
#   'target': ' jazz',
#   'premise': 'Freddy Cole performs radiation Freddy Cole performs',
#   'orthogonal_token': ' radiation',
#   'length': 9},
#  {'prompt': 'Alban Berg plays',
#   'target': ' opera',
#   'premise': 'Alban Berg plays faults Alban Berg plays',
#   'orthogonal_token': ' faults',
#   'length': 9},
#  ...]
